# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/Vinnicius-Stein/-Distributed-Systems/main/dataset_00_1000.csv")

df.head()
# Out:
#    idatracacao    cdtup  ... cdmercadoria_cntr pesocarga_cntr
# 0       788883    BRCDO  ...               NaN            NaN
# 1       751889    BRBEL  ...               NaN            NaN
# 2       751889    BRBEL  ...               NaN            NaN
# 3       797313  BRSE002  ...               NaN            NaN
# 4       794159  BRAM011  ...               NaN            NaN
#
# [5 rows x 27 columns]

# %%
df.tail()
# Out:
#      idatracacao  cdtup berco  ...        sentido  cdmercadoria_cntr pesocarga_cntr
# 995       795383  BRARE    T1  ...  Desembarcados                NaN            NaN
# 996       763342  BRARE    T1  ...  Desembarcados                NaN            NaN
# 997       738136  BRARE    T1  ...  Desembarcados                NaN            NaN
# 998       735794  BRARE    T1  ...  Desembarcados                NaN            NaN
# 999       786001  BRARE    T1  ...  Desembarcados                NaN            NaN
#
# [5 rows x 27 columns]
